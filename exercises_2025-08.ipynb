# %% [markdown]
# # Walkthroughs and Exercises for Statistical Modeling and Inference with Python
#
# Dr. Chester Ismay
#
# # Week 1
#
# ## Walkthrough 1.1: Getting Started
#
# ### Setting Up the Python Environment
#
# If you haven’t already installed Python, Jupyter, and the necessary
# packages, there are instructions on the course repo in the README to do
# so
# [here](https://github.com/ismayc/oreilly-fundamentals-of-statistics-with-python/blob/main/README.md).
#
# If you aren’t able to do this on your machine, you may want to check out
# [Google Colab](https://colab.research.google.com/). It’s a free service
# that allows you to run Jupyter notebooks in the cloud.

# %%
# Install the necessary packages if needed
# !pip install numpy pandas scipy matplotlib seaborn statsmodels scikit-learn

# Importing libraries/modules and aliasing them as needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn

# %% [markdown]
# ### Load a dataset

# %%
# Load in the dataset
spotify_sample = pd.read_csv("spotify_sample.csv")
spotify_sample
# Out:
#                     track_id                     artists  \
# 0     2IVsRhKrx8hlQBOWy4qebo            Ricky Montgomery
# 1     5Odq8ohlgIbQKMZivbWkEo  Charlie Puth;Jung Kook;BTS
# 2     4jbmgIyjGoXjY01XxatOx6          Katy Perry;Juicy J
# 3     37EJtTS7jT5WUyXGZzrwnI                   Everclear
# 4     1roCmBlcpV7LzsmB7pmCyt  Alec Benjamin;Alessia Cara
# ...                      ...                         ...
# 2019  5cF0dROlMOK5uNZtivgu50                Charlie Puth
# 2020  2RiBogNRfulkNf7fVbPOrJ                   Vance Joy
# 2021  06WUUNf7q18NZfjIsQFsfa                      Slayer
# 2022  4aYLAF6ckQ5ooGGGM7sWAa                   Metallica
# 2023  6H3kDe7CGoWYBabAeVWGiD          The Rolling Stones
#
#                                    album_name  \
# 0                            Montgomery Ricky
# 1                                     CHARLIE
# 2                                       PRISM
# 3                            Sparkle And Fade
# 4     Let Me Down Slowly (feat. Alessia Cara)
# ...                                       ...
# 2019                               Voicenotes
# 2020                            Nation of Two
# 2021                               Repentless
# 2022                                Metallica
# 2023                             Let It Bleed
#
#                                    track_name  popularity  duration_ms  \
# 0                                 Mr Loverman          79       216880
# 1     Left and Right (Feat. Jung Kook of BTS)          75       154486
# 2                                  Dark Horse          78       215672
# 3                                Santa Monica          71       191506
# 4     Let Me Down Slowly (feat. Alessia Cara)          71       169174
# ...                                       ...         ...          ...
# 2019                                Attention          83       208786
# 2020                             Saturday Sun          71       214720
# 2021                     Delusions of Saviour          73       115413
# 2022                           The Unforgiven          74       386493
# 2023                            Gimme Shelter          77       270773
#
#       explicit  danceability  energy  key  loudness  mode  speechiness  \
# 0        False         0.639   0.526    0    -6.697     1       0.0256
# 1        False         0.881   0.592    2    -4.898     1       0.0324
# 2        False         0.647   0.585    6    -6.123     1       0.0512
# 3        False         0.491   0.942    7    -5.333     1       0.1320
# 4        False         0.655   0.569    1    -5.018     0       0.0349
# ...        ...           ...     ...  ...       ...   ...          ...
# 2019     False         0.775   0.613    3    -4.586     0       0.0542
# 2020     False         0.637   0.864    8    -4.381     1       0.0468
# 2021     False         0.223   0.805    8    -8.969     1       0.0370
# 2022     False         0.540   0.584    7    -9.579     1       0.0254
# 2023     False         0.634   0.630    1    -8.277     0       0.0310
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.245000          0.000024    0.2500    0.488  130.033
# 1         0.619000          0.000013    0.0901    0.719  101.058
# 2         0.003140          0.000000    0.1650    0.353  131.934
# 3         0.156000          0.000000    0.3670    0.387  100.446
# 4         0.716000          0.000007    0.1350    0.440  150.267
# ...            ...               ...       ...      ...      ...
# 2019      0.109000          0.000023    0.1340    0.797  100.066
# 2020      0.484000          0.000000    0.2220    0.706   99.995
# 2021      0.000179          0.814000    0.0849    0.250  168.165
# 2022      0.010800          0.002960    0.2530    0.244  139.261
# 2023      0.447000          0.039000    0.1700    0.489  118.628
#
#       time_signature track_genre
# 0                  3   indie-pop
# 1                  4       dance
# 2                  4       dance
# 3                  4      grunge
# 4                  4     electro
# ...              ...         ...
# 2019               4       dance
# 2020               4        folk
# 2021               4    alt-rock
# 2022               4   hard-rock
# 2023               4     british
#
# [2024 rows x 20 columns]

# %% [markdown]
# ### Prepare data

# %%
# Select a single feature (acousticness) and target variable (energy)
X = spotify_sample[['acousticness']]
y = spotify_sample['energy']

# %% [markdown]
# ### Create the model

# %%
from sklearn.linear_model import LinearRegression

# Create and fit the model
model = LinearRegression()
model.fit(X, y)

# Accousticness coefficient 
model.coef_
# Out:
# array([-0.47021382])

# %%
# and the intercept value
model.intercept_
# Out:
# np.float64(0.7713193659794643)

# %% [markdown]
# ### Make predictions

# %%
# Store predicted values for each value of X
y_pred = model.predict(X)

# Define a new data point for prediction
new_data_point = pd.DataFrame({'acousticness': [0.35]})

# Make prediction
predicted_energy = model.predict(new_data_point)

print(f"Predicted energy for acousticness =",
      f"{new_data_point.iloc[0, 0]}: {round(predicted_energy[0], 2)}")
# Out:
# Predicted energy for acousticness = 0.35: 0.61

# %% [markdown]
# ### Visualize the regression line

# %%
# Plotting the results
sns.scatterplot(x=X.acousticness, y=y, color='blue',
                label='Actual Data');
sns.lineplot(x=X.acousticness, y=y_pred, color='red',
             label='Regression Line Prediction', linewidth=2)
# Out:
# <Axes: xlabel='acousticness', ylabel='energy'>

# %% [markdown]
# ### Check if assumptions of linear regression met with visual tools

# %%
# Check for Homoscedasticity
residuals = y - y_pred
plt.figure(figsize=(10, 2))
sns.scatterplot(x=y_pred, y=residuals, alpha=0.4)
plt.axhline(y=0, color='green', linestyle='--')

# %%
# Check for Normality of Residuals
plt.figure(figsize=(10, 2))
sns.histplot(residuals, kde=True)
# Out:
# <Axes: xlabel='energy', ylabel='Count'>

# %%
# Make QQ plot
sm.qqplot(residuals, line='s')

# %% [markdown]
# ## Exercise 1.1: Getting Started
#
# ### Setting Up the Python Environment
#
# If you ran the `# Importing libraries and aliasing them` code above, you
# should be good to proceed here. If not, scroll up and run it.
#
# ### Load a dataset

# %%
# Load in the dataset
imdb_movie_sample = pd.read_csv("imdb_movie_sample.csv")

# %% [markdown]
# ### Prepare data

# %%
# Select a single feature (votes) and target variable (rating)

# %% [markdown]
# ### Create the model

# %%
# Create and fit the model

# %%
# Votes coefficient and intercept

# %% [markdown]
# ### Make predictions

# %%
# Store predicted values for each value of X

# %%
# Define a new data point for prediction (200,000 votes)

# %%
# Make prediction

# %%
# Output results
print(f"Predicted rating for votes = ",
      f"{new_imdb_data.iloc[0, 0]}: {round(predicted_rating[0], 2)}")

# %% [markdown]
# ### Visualize the regression line

# %%
# Plotting the results

# %% [markdown]
# ### Check if assumptions of linear regression met with visual tools

# %%
# Check for Homoscedasticity

# %%
# Check for Normality of Residuals

# %% [markdown]
# ## Walkthrough 1.2: Correlation
#
# ### Correlation matrix

# %%
# Select only numeric columns
numeric_columns = spotify_sample.select_dtypes(include=[np.number])

# Calculate Pearson correlation matrix
correlation_matrix = numeric_columns.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                   popularity  duration_ms  danceability    energy       key  \
# popularity          1.000000    -0.082278      0.127532  0.010058 -0.027631
# duration_ms        -0.082278     1.000000     -0.264755  0.008741  0.028283
# danceability        0.127532    -0.264755      1.000000  0.079812  0.032541
# energy              0.010058     0.008741      0.079812  1.000000  0.010671
# key                -0.027631     0.028283      0.032541  0.010671  1.000000
# loudness            0.086216    -0.083199      0.222743  0.722339  0.009225
# mode               -0.035483     0.047103     -0.128635 -0.082894 -0.120635
# speechiness         0.044336    -0.125077      0.229544  0.101975  0.067418
# acousticness       -0.066714    -0.047906     -0.092686 -0.634235  0.003188
# instrumentalness   -0.056118     0.028249     -0.169265 -0.149437  0.014540
# liveness           -0.008901    -0.015372     -0.064824  0.155328 -0.009253
# valence            -0.020808    -0.132867      0.418431  0.373744  0.007458
# tempo              -0.009479    -0.036287     -0.129809  0.149471 -0.011600
# time_signature     -0.006527    -0.056409      0.225751  0.209150 -0.024072
#
#                   loudness      mode  speechiness  acousticness  \
# popularity        0.086216 -0.035483     0.044336     -0.066714
# duration_ms      -0.083199  0.047103    -0.125077     -0.047906
# danceability      0.222743 -0.128635     0.229544     -0.092686
# energy            0.722339 -0.082894     0.101975     -0.634235
# key               0.009225 -0.120635     0.067418      0.003188
# loudness          1.000000 -0.094020     0.094559     -0.476257
# mode             -0.094020  1.000000    -0.064826      0.106039
# speechiness       0.094559 -0.064826     1.000000     -0.052236
# acousticness     -0.476257  0.106039    -0.052236      1.000000
# instrumentalness -0.340739  0.048699    -0.066858      0.125129
# liveness          0.101894  0.007828     0.027345     -0.090550
# valence           0.245695 -0.010206     0.104855     -0.203975
# tempo             0.097394 -0.018432     0.132441     -0.129973
# time_signature    0.230465 -0.056068     0.079879     -0.188187
#
#                   instrumentalness  liveness   valence     tempo  \
# popularity               -0.056118 -0.008901 -0.020808 -0.009479
# duration_ms               0.028249 -0.015372 -0.132867 -0.036287
# danceability             -0.169265 -0.064824  0.418431 -0.129809
# energy                   -0.149437  0.155328  0.373744  0.149471
# key                       0.014540 -0.009253  0.007458 -0.011600
# loudness                 -0.340739  0.101894  0.245695  0.097394
# mode                      0.048699  0.007828 -0.010206 -0.018432
# speechiness              -0.066858  0.027345  0.104855  0.132441
# acousticness              0.125129 -0.090550 -0.203975 -0.129973
# instrumentalness          1.000000 -0.042264 -0.155218 -0.035381
# liveness                 -0.042264  1.000000  0.041816  0.030017
# valence                  -0.155218  0.041816  1.000000  0.033820
# tempo                    -0.035381  0.030017  0.033820  1.000000
# time_signature           -0.131703  0.018666  0.186840 -0.003579
#
#                   time_signature
# popularity             -0.006527
# duration_ms            -0.056409
# danceability            0.225751
# energy                  0.209150
# key                    -0.024072
# loudness                0.230465
# mode                   -0.056068
# speechiness             0.079879
# acousticness           -0.188187
# instrumentalness       -0.131703
# liveness                0.018666
# valence                 0.186840
# tempo                  -0.003579
# time_signature          1.000000

# %% [markdown]
# ### Visualizing correlation matrix

# %%
# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Visualizing relationships

# %%
# Plot pairplot to visualize relationships
sns.pairplot(
    numeric_columns[['danceability', 'energy', 'loudness', 'valence', 'popularity']]
)

# %% [markdown]
# ## Exercise 1.2: Correlation
#
# ### Correlation matrix

# %%
# Select only numeric columns


# Calculate Pearson correlation matrix


# Display the correlation matrix

# %% [markdown]
# ## Visualizing correlation matrix

# %%
# Visualize the correlation matrix using a heatmap

# %% [markdown]
# ### Visualizing relationships

# %%
# Plot pairplot to visualize relationships of 
# runtime_in_minutes, rating, votes, and gross_in_dollars

# %% [markdown]
# ## Walkthrough 1.3: Multiple Regression

# %%
# Prepare the data for multiple regression by choosing 
# Predictors: danceability, energy, and loudness
# Response: popularity
X = spotify_sample[['danceability', 'energy', 'loudness']]
y = spotify_sample['popularity']

# Fit the multiple regression model
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# Coefficients and intercept
model.coef_
model.intercept_

# Plot predicted vs. actual
plt.figure(figsize=(10,2))
sns.scatterplot(x=y, y=y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--', 
         label="Perfect Fit")
plt.xlabel('Actual Popularity')
plt.ylabel('Predicted Popularity')
# Out:
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# Text(0, 0.5, 'Predicted Popularity')

# %% [markdown]
# ## Exercise 1.3: Multiple Regression

# %%
# Prepare the data for multiple regression by choosing 
# Predictors: runtime_in_minutes, votes, and gross_in_dollars
# Response: rating


# Fit the model

# Coefficients and intercept

# Plot predicted vs. actual
# Out:
# Coefficients: [ 0.0133726   0.00000255 -0.00000001]

# %% [markdown]
# ## Walkthrough 1.4: Logistic Regression
#
# ### Logistic Regression with a Single Predictor

# %%
from sklearn.linear_model import LogisticRegression

# Set loudness as predictor/feature and binarize energy: high energy = 1
X = spotify_sample[['loudness']]
y = (spotify_sample['energy'] > 0.6).astype(int)

# %%
# Fit model
model = LogisticRegression()
model.fit(X, y)
# Out:
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: divide by zero encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: overflow encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:330: RuntimeWarning: invalid value encountered in matmul
#   grad[:n_features] = X.T @ grad_pointwise + l2_reg_strength * weights
# LogisticRegression()

# %%
# Predict over a smooth range
x_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
probs = model.predict_proba(x_vals)[:, 1]
# Out:
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# Plot predicted and actual energy against loudness
plt.figure(figsize=(10,2))
plt.plot(x_vals, probs, color='red', label='Predicted Probabilities (S-curve)')
plt.scatter(X, y, alpha=0.4, color='gray', label='Actual points')
plt.xlabel('Loudness')
plt.ylabel('Probability of High Energy')
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Logistic Regression with Multiple Predictors

# %%
# Define predictors (loudness and acousticness) and binary energy response
X = spotify_sample[['loudness', 'acousticness']]
y = (spotify_sample['energy'] > 0.6).astype(int)

# %%
# Fit the logistic regression model
model = LogisticRegression()
model.fit(X, y)
# Out:
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept
# LogisticRegression()

# %%
# Predict probabilities
spotify_sample['predicted_prob'] = model.predict_proba(X)[:, 1]
# Out:
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b

# %%
model.predict_proba(X)
# Out:
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# array([[0.33708014, 0.66291986],
#        [0.4247587 , 0.5752413 ],
#        [0.13455923, 0.86544077],
#        ...,
#        [0.41917914, 0.58082086],
#        [0.51087703, 0.48912297],
#        [0.71321892, 0.28678108]])

# %%
# Plot the predicted probabilities
plt.figure(figsize=(10,2))
sns.histplot(spotify_sample['predicted_prob'])
# Out:
# <Axes: xlabel='predicted_prob', ylabel='Count'>

# %%
# Scatter plot: predicted probability vs actual outcome
plt.figure(figsize=(10,2))
sns.scatterplot(x=spotify_sample['predicted_prob'], y=y, alpha=0.3);
plt.title('Predicted Probability vs Actual High Popularity');
plt.xlabel('Predicted Probabilities');
plt.ylabel('Actual (0 = Low Popularity, 1 = High Popularity)');

# %% [markdown]
# ## Exercise 1.4: Logistic Regression
#
# ### Logistic Regression with a Single Predictor

# %%
# Define votes predictor and 
# binary rating response (rating > 7 -> high rating)

# %%
# Fit model

# %%
# Predict over a smooth range
x_vals = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
probs = model.predict_proba(x_vals)[:, 1]

# %%
# Plot predicted and actual energy against loudness

# %% [markdown]
# ### Logistic Regression with Multiple Predictors

# %%
# Define predictors (runtime_in_minutes and votes) and 
# binary rating response (rating > 7 -> high rating)

# %%
# Fit the model

# %%
# Predict probabilities

# %%
# Plot the predicted probabilities

# %%
# Scatter plot: predicted probability vs actual outcome

# %% [markdown]
# ## Walkthrough 1.5: ANOVA
#
# ### One-way ANOVA

# %%
from statsmodels.formula.api import ols

# Choose some genres to compare
genres = ['pop', 'rock', 'hip-hop', 'jazz']

# %%
# Subset the data to focus only on these genres
spotify_sample_subset = spotify_sample[spotify_sample.track_genre.isin(genres)]

# %%
# Perform one-way ANOVA analyzing energy across different genres
model = ols('energy ~ C(track_genre)', data=spotify_sample_subset).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                   sum_sq     df        F    PR(>F)
# C(track_genre)  0.693407    3.0  9.11268  0.000011
# Residual        5.275748  208.0      NaN       NaN

# %% [markdown]
# ### Boxplot across groups

# %%
# Boxplot for visualization
sns.boxplot(x='energy', y='track_genre', data=spotify_sample_subset)
# Out:
# <Axes: xlabel='energy', ylabel='track_genre'>

# %% [markdown]
# ### Two-way ANOVA

# %%
# Perform two-way ANOVA analyzing energy across genres and explicit content
model = ols('energy ~ C(track_genre) * C(explicit)', data=spotify_sample_subset).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
# /Users/chesterismay/.virtualenvs/r-reticulate/lib/python3.9/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
#                               sum_sq     df         F    PR(>F)
# C(track_genre)              0.417445    3.0  5.433314  0.005021
# C(explicit)                 0.012582    1.0  0.491274  0.484154
# C(track_genre):C(explicit)  0.036156    3.0  0.470592  0.625305
# Residual                    5.250099  205.0       NaN       NaN

# %% [markdown]
# ### Boxplot across groups with color added

# %%
# Boxplot for visualization
plt.figure(figsize=(10, 4))
sns.boxplot(x='track_genre', y='energy', hue='explicit', 
            data=spotify_sample_subset)
plt.legend(title = "Explicit")

# %% [markdown]
# ## Exercise 1.5: ANOVA
#
# ### One-way ANOVA

# %%
# Choose some genres to compare ('Action', 'Crime', 'Horror', 'Romance')
movie_genres = ['Action', 'Crime', 'Horror', 'Romance']

# Subset the data to focus only on these genres

# Perform one-way ANOVA analyzing rating across different genres

# %% [markdown]
# ### Boxplot across groups

# %%
# Boxplot for visualization

# %% [markdown]
# ### Two-way ANOVA

# %%
# Perform two-way ANOVA analyzing rating across genres and decades

# %% [markdown]
# ### Boxplot across groups with color added

# %%
# Some customization here to get the decades to appear in the appropriate order

# Define the ordered categories
decades = ['1940s', '1950s', '1960s', '1970s', '1980s', '1990s', 
           '2000s', '2010s', '2020s']

# Convert 'decade' column to a categorical type with ordered categories
imdb_movie_sample_subset['decade'] = pd.Categorical(
  imdb_movie_sample_subset['decade'], categories=decades, ordered=True)

# Boxplot for visualization

# %% [markdown]
# # Week 2
#
# ## Walkthrough 2.1: Kruskal-Wallis and Mann-Whitney U Tests
#
# ### Kruskal-Wallis

# %%
import scipy.stats as stats

# Perform Kruskal-Wallis Test on 'danceability' grouped by 'track_genre'
grouped_data = [ group['danceability'].values 
                 for name, group in spotify_sample.groupby("track_genre") ]
stat, p_value = stats.kruskal(*grouped_data)
stat
# Out:
# np.float64(716.1550864769308)

# %%
p_value
# Out:
# np.float64(8.079896027452027e-106)

# %% [markdown]
# ### Mann-Whitney U

# %%
# Perform Mann-Whitney U Test on 'energy' for pop versus rock
group1 = spotify_sample[ spotify_sample.track_genre == "pop"]["energy"]
group2 = spotify_sample[ spotify_sample.track_genre == "rock"]["energy"]
u_stat, p_value = stats.mannwhitneyu(group1, group2)
u_stat
# Out:
# np.float64(1331.5)

# %%
print(f"P-value: {p_value}")
# Out:
# P-value: 0.006209251182150306

# %% [markdown]
# ## Exercise 2.1: Kruskal-Wallis and Mann-Whitney U Tests
#
# ### Kruskal-Wallis

# %%
# Perform Kruskal-Wallis Test on 'rating' grouped by 'decade'

# %% [markdown]
# ### Mann-Whitney U

# %%
# Perform Mann-Whitney U Test on 'gross_in_dollars' for 1990s versus 2000s

# %% [markdown]
# ## Walkthrough 2.2: Correlation and Regression Non-parametrics
#
# ### Spearman’s Rank Correlation

# %%
from scipy.stats import spearmanr, kendalltau
from sklearn.linear_model import TheilSenRegressor

# Filter numeric columns
numeric_columns = spotify_sample.select_dtypes(include=[np.number])

# Calculate Spearman's rank correlation matrix
spearman_corr = numeric_columns.corr(method='spearman')

# Calculate Pearson's correlation matrix (so we can compare)
pearson_corr = numeric_columns.corr(method='pearson')

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Spearman Rank Correlation Matrix')
plt.tight_layout()
plt.show();

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Pearson Correlation Matrix')
plt.tight_layout()
plt.show();

# %% [markdown]
# ### Kendall’s Tau Correlation

# %%
# Calculate Kendall's tau correlation matrix
kendall_corr = numeric_columns.corr(method='kendall')

plt.figure(figsize=(10, 8))
sns.heatmap(kendall_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Kendall's Tau Correlation Matrix")
plt.tight_layout()
plt.show();

# %% [markdown]
# ### Theil-Sen Robust Regression

# %%
# Theil-Sen robust regression for 'danceability' and 'energy' 
# predicting 'popularity'
X = numeric_columns[['danceability', 'energy']]
y = numeric_columns['popularity']
theil_sen = TheilSenRegressor()
theil_sen.fit(X, y)
# Out:
# TheilSenRegressor()

# %%
print("Intercept:", theil_sen.intercept_)
# Out:
# Intercept: 73.44734759257521

# %%
print("Coefficients (danceability first, energy second):", theil_sen.coef_)
# Out:
# Coefficients (danceability first, energy second): [ 3.09992119 -0.28947504]

# %% [markdown]
# ## Exercise 2.2: Correlation and Regression Non-parametrics
#
# ### Spearman’s Rank Correlation

# %%
# Filter numeric columns

# Calculate Spearman's rank correlation matrix

# %% [markdown]
# ### Kendall’s Tau Correlation

# %%
# Calculate Kendall's tau correlation matrix

# %% [markdown]
# ### Theil-Sen Robust Regression

# %%
# Theil-Sen robust regression for 'votes' and 'runtime_in_minutes' predicting 'rating'
# Out:
# Coefficients: [0.00000366 0.01350147]

# %% [markdown]
# ## Walkthrough 2.3: Bootstrapping

# %%
# Function to perform bootstrapping
def bootstrap(data, n_bootstrap_samples=1000):
    statistics = []
    # Repeat a specified number of times
    for _ in range(n_bootstrap_samples):
        # Create a resample of the original data (of the same size)
        resample = data.sample(replace=True, frac=1)
        # Calculating a mean (but it could be a different calculation)
        bootstrap_statistic = resample.mean()
        # Put that calculation into the list above
        statistics.append(bootstrap_statistic)
    return statistics

# Perform bootstrapping on the 'energy' column
bootstrap_means = bootstrap(spotify_sample['energy'],
                            n_bootstrap_samples=20000)

# Plot the distribution of bootstrap means
plt.hist(bootstrap_means, bins=30, edgecolor='k')
plt.title("Distribution of Bootstrap Means for Energy");

# %% [markdown]
# ## Exercise 2.3: Bootstrapping

# %%
# Perform bootstrapping on the 'runtime_in_minutes' column
# using the bootstrap function defined above


# Plot the distribution of bootstrap means

# %% [markdown]
# ## Walkthrough 2.4: Confidence Intervals

# %%
# Function to calculate bootstrap confidence intervals
def bootstrap_confidence_interval(data, n_bootstrap_samples=10_000, confidence_level=0.95):
    statistics = []
    for _ in range(n_bootstrap_samples):
        resample = data.sample(frac=1, replace=True)
        statistics.append(resample.mean())
    lower_bound = np.percentile(statistics, (1 - confidence_level) / 2 * 100)
    upper_bound = np.percentile(statistics, (1 + confidence_level) / 2 * 100)
    return lower_bound, upper_bound
    
# Calculate confidence intervals for the 'energy' column
lower, upper = bootstrap_confidence_interval(spotify_sample['energy'])
print(f"95% Confidence Interval for Population Mean Energy: [{lower}, {upper}]")
# Out:
# 95% Confidence Interval for Population Mean Energy: [0.6554293451086958, 0.6719094950592884]

# %%
# Plot the distribution of bootstrap means and confidence interval
bootstrap_means = bootstrap(spotify_sample['energy'],
                            n_bootstrap_samples=10000)
plt.hist(bootstrap_means, edgecolor='k', bins=50)
plt.axvline(lower, color='green', linestyle="--")
plt.axvline(upper, color='green', linestyle="--")
plt.title("Bootstrap Means and Corresponding 95% Confidence Interval for Energy")
plt.show();

# %% [markdown]
# ## Exercise 2.4: Confidence Intervals

# %%
# Calculate confidence intervals for the 'rating' column using the
# bootstrap_confidence_interval function defined above

# %% [markdown]
# ## Walkthrough 2.5: Real-World Scenarios for Bootstrapping
#
# **Music Industry Analytics**
#
# *Objective*: Analyzing song popularity and estimating population mean
# popularity.
#
# *Scenario*: You are a data scientist for a movie production company.
# Your role is to analyze movie ratings and predict the average rating of
# movies produced. By using bootstrapping techniques, you aim to estimate
# the mean movie rating and its variability to understand the unknown
# population mean.
#
# *Bootstrapping Applications*:
#
# -   *Estimating Average Popularity*: Use bootstrapping to calculate the
#     mean and confidence intervals of the popularity scores.
# -   *Assessing Variability*: Determine the variability in the means of
#     song popularity.

# %%
# Calculate bootstrap statistics for the 'popularity' column

# Function to calculate bootstrap statistics

# %% [markdown]
# ## Exercise 2.5: Real-World Scenarios for Bootstrapping
#
# **Film Industry Insights**
#
# *Objective*: Evaluating movie gross revenue and estimating population
# mean gross revenue.
#
# *Scenario*: You are a data scientist for a movie production company.
# Your role is to analyze movie gross revenue and predict the average
# gross revenue of movies produced. By using bootstrapping techniques, you
# aim to estimate the mean gross revenue and its variability to understand
# the unknown population mean.
#
# *Bootstrapping Applications*:
#
# -   *Estimating Average Gross Revenue*: Use bootstrapping to calculate
#     the mean and confidence intervals of movie gross revenue.
# -   *Assessing Variability*: Determine the variability in the means of
#     movie gross revenue.

# %%
# Calculate bootstrap statistics for the 'gross_in_dollars' column
# using the function called bootstrap_statistics defined above
